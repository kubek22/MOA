# %%
import pulp
from pulp import LpProblem, LpMaximize
import numpy as np

# %%
# init model
model = LpProblem("TeaDistributionTask", LpMaximize)

# %%
ANNUAL_COST = 1500000
MARKETING_COST = 150000

# %%
# declare variables
tea_types = ['GT', 'BT', 'WT', 'RT']
box_sizes = [50, 100]
countries = ['PT', 'ES', 'FR', 'IT', 'DE', 'PL']

x = pulp.LpVariable.dicts(
    "x",
    ((i, j, k) for i in tea_types for j in box_sizes for k in countries),
    lowBound=0,
    cat='Integer'
)

# %%
# selling prices
P = np.array([
    [6, 10],
    [7, 12],
    [9, 16],
    [8, 14]
])

# raw tea cost # additional constraint may be needed (if we sell odd number of 50g boxes of one kind, we must add the full price because we can only buy 100g boxes)
C = np.array([
    [1.75, 3.5],
    [2.25, 4.5],
    [2.75, 5.5],
    [2.5, 5.0]
])

# distribution cost per country
D = np.array([0.5, 0.4, 0.6, 0.7, 0.8, 1.0])

# %%
# index mappings
i_index = {tea_types[i]: i for i in range(len(tea_types))}
j_index = {box_sizes[j]: j for j in range(len(box_sizes))}
k_index = {countries[k]: k for k in range(len(countries))}

# %%
# objective function

model += pulp.lpSum(
    (P[i_index[i], j_index[j]] - C[i_index[i], j_index[j]] - D[k_index[k]] - 1) * x[i, j, k]
    for i in tea_types
    for j in box_sizes
    for k in countries
) - MARKETING_COST - ANNUAL_COST

# %%
# constraints

# max total number of boxes produced
model += pulp.lpSum(
    x[i, j, k]
    for i in tea_types
    for j in box_sizes
    for k in countries
) <= 2 * 1e6

# max amount of available tea
model += pulp.lpSum(j * x['GT', j, k] for j in box_sizes for k in countries) <= 25 * 1e6
model += pulp.lpSum(j * x['BT', j, k] for j in box_sizes for k in countries) <= 30 * 1e6
model += pulp.lpSum(j * x['WT', j, k] for j in box_sizes for k in countries) <= 15 * 1e6
model += pulp.lpSum(j * x['RT', j, k] for j in box_sizes for k in countries) <= 20 * 1e6

# min 10% of total production
total = pulp.lpSum(x[i, j, k] for i in tea_types for j in box_sizes for k in countries)
model += pulp.lpSum(x['GT', j, k] for j in box_sizes for k in countries) >= total * 0.1
model += pulp.lpSum(x['BT', j, k] for j in box_sizes for k in countries) >= total * 0.1
model += pulp.lpSum(x['WT', j, k] for j in box_sizes for k in countries) >= total * 0.1
model += pulp.lpSum(x['RT', j, k] for j in box_sizes for k in countries) >= total * 0.1

# demand forecast
F_MULT = 100
F = np.array([
    # GT (Green Tea)
    [
        [100, 150, 200, 130, 180, 120],  # 50g
        [ 80, 120, 170, 110, 160, 100]   # 100g
    ],
    # BT (Black Tea)
    [
        [ 90, 130, 180, 120, 170, 110],  # 50g
        [ 70, 110, 160, 100, 150,  90]   # 100g
    ],
    # WT (White Tea)
    [
        [ 50,  80, 100,  70,  90,  60],  # 50g
        [ 40,  60,  90,  60,  80,  50]   # 100g
    ],
    # RT (Red Tea)
    [
        [ 60, 100, 120,  90, 110,  80],  # 50g
        [ 50,  90, 110,  80, 100,  70]   # 100g
    ]
]) * F_MULT

for i in tea_types:
    for j in box_sizes:
        for k in countries:
            model += x[i, j, k] <= F[i_index[i], j_index[j], k_index[k]]

# %%
# solving the problem
model.solve()
# Out:
# 1

# %% [markdown]
# ## Results

# %%
total_boxes = sum(x[i, j, k].varValue 
                  for i in tea_types 
                  for j in box_sizes 
                  for k in countries)

print("Total number of boxes:", total_boxes)
# Out:
# Total number of boxes: 499000.0

# %%
for k in countries:
    country_boxes = sum(x[i, j, k].varValue for i in tea_types for j in box_sizes)
    print(f"Total number of boxes in {k}:", country_boxes)
# Out:
# Total number of boxes in PT: 54000.0
# Total number of boxes in ES: 84000.0
# Total number of boxes in FR: 113000.0
# Total number of boxes in IT: 76000.0
# Total number of boxes in DE: 104000.0
# Total number of boxes in PL: 68000.0

# %%
for i in tea_types:
    country_boxes = sum(x[i, j, k].varValue for j in box_sizes for k in countries)
    print(f"Total number of boxes of {i}:", country_boxes)
    for j in box_sizes:
        country_type_boxes = sum(x[i, j, k].varValue for k in countries)
        print(f"Total number of {j}g boxes of {i}: {country_type_boxes}")
    print()
# Out:
# Total number of boxes of GT: 162000.0
# Total number of 50g boxes of GT: 88000.0
# Total number of 100g boxes of GT: 74000.0
#
# Total number of boxes of BT: 148000.0
# Total number of 50g boxes of BT: 80000.0
# Total number of 100g boxes of BT: 68000.0
#
# Total number of boxes of WT: 83000.0
# Total number of 50g boxes of WT: 45000.0
# Total number of 100g boxes of WT: 38000.0
#
# Total number of boxes of RT: 106000.0
# Total number of 50g boxes of RT: 56000.0
# Total number of 100g boxes of RT: 50000.0

# %%
for j in box_sizes:
    country_boxes = sum(x[i, j, k].varValue for i in tea_types for k in countries)
    print(f"Total number of boxes of size {j}g:", country_boxes)
# Out:
# Total number of boxes of size 50g: 269000.0
# Total number of boxes of size 100g: 230000.0

# %%
revenue = sum(P[i_index[i], j_index[j]] * x[i, j, k].varValue for i in tea_types for j in box_sizes for k in countries)
print(f"Total revenue: {revenue}")
# Out:
# Total revenue: 4805000.0

# %%
revenue = sum(P[i_index[i], j_index[j]] * x[i,j,k].varValue 
              for i in tea_types 
              for j in box_sizes 
              for k in countries)

raw_cost = sum(C[i_index[i], j_index[j]] * x[i,j,k].varValue 
               for i in tea_types 
               for j in box_sizes 
               for k in countries)

dist_cost = sum(D[k_index[k]] * x[i,j,k].varValue 
                for i in tea_types 
                for j in box_sizes 
                for k in countries)

prod_mark_cost = sum(1 * x[i,j,k].varValue
                     for i in tea_types 
                     for j in box_sizes 
                     for k in countries)

fixed_cost = MARKETING_COST + ANNUAL_COST

operating_income = revenue - (raw_cost + dist_cost + prod_mark_cost + fixed_cost)

print("Revenue:", revenue)
print("Raw tea cost:", raw_cost)
print("Distribution cost:", dist_cost)
print("Boxes production cost:", prod_mark_cost)
print("Fixed cost:", fixed_cost)
print("Operating income:", operating_income)
# Out:
# Revenue: 4805000.0
# Raw tea cost: 1621750.0
# Distribution cost: 332800.0
# Boxes production cost: 499000.0
# Fixed cost: 1650000
# Operating income: 701450.0

# %%
# weight constraint
gram_constr = [25, 30, 15, 20]
for i in tea_types:
    tea_grams = sum(j * x[i, j, k].varValue for j in box_sizes for k in countries)
    print(f"Grams of {i}: {tea_grams}, constraint: {gram_constr[i_index[i]] * 1e6}, within constraint: {tea_grams <= gram_constr[i_index[i]] * 1e6}")
# Out:
# Grams of GT: 11800000.0, constraint: 25000000.0, within constraint: True
# Grams of BT: 10800000.0, constraint: 30000000.0, within constraint: True
# Grams of WT: 6050000.0, constraint: 15000000.0, within constraint: True
# Grams of RT: 7800000.0, constraint: 20000000.0, within constraint: True

# %%
# market presence constraint
print(f"Min constraint: {total_boxes * 0.1}\n")
total_boxes = sum(x[i, j, k].varValue for i in tea_types for j in box_sizes for k in countries)
for i in tea_types:
    tea_boxes = sum(x[i, j, k].varValue for j in box_sizes for k in countries)
    print(f"Within market presence constraint for {i}: {tea_boxes >= total_boxes * 0.1}")
    print(f"{i} boxes: {tea_boxes}")
    print(f"")
# Out:
# Min constraint: 49900.0
#
# Within market presence constraint for GT: True
# GT boxes: 162000.0
#
# Within market presence constraint for BT: True
# BT boxes: 148000.0
#
# Within market presence constraint for WT: True
# WT boxes: 83000.0
#
# Within market presence constraint for RT: True
# RT boxes: 106000.0

# %%
def check_constraints(problem):
    for name, constraint in problem.constraints.items():
        lhs_value = abs(pulp.value(constraint))
        rhs = abs(constraint.constant)
        sense = constraint.sense
        if (sense == pulp.LpConstraintLE and lhs_value > rhs) or \
           (sense == pulp.LpConstraintGE and lhs_value < rhs) or \
           (sense == pulp.LpConstraintEQ and lhs_value != rhs):
            print(f"Constraint {name} violated! LHS={lhs_value}, RHS={rhs}")
        else:
            print(f"Constraint {name} satisfied. LHS={lhs_value}, RHS={rhs}")

check_constraints(model)

# No constraints are violated
# Out:
# Constraint _C1 satisfied. LHS=1501000.0, RHS=2000000.0
# Constraint _C2 satisfied. LHS=13200000.0, RHS=25000000.0
# Constraint _C3 satisfied. LHS=19200000.0, RHS=30000000.0
# Constraint _C4 satisfied. LHS=8950000.0, RHS=15000000.0
# Constraint _C5 satisfied. LHS=12200000.0, RHS=20000000.0
# Constraint _C6 satisfied. LHS=112100.0, RHS=0.0
# Constraint _C7 satisfied. LHS=98100.0, RHS=0.0
# Constraint _C8 satisfied. LHS=33100.0, RHS=0.0
# Constraint _C9 satisfied. LHS=56100.0, RHS=0.0
# Constraint _C10 satisfied. LHS=0.0, RHS=10000
# Constraint _C11 satisfied. LHS=0.0, RHS=15000
# Constraint _C12 satisfied. LHS=0.0, RHS=20000
# Constraint _C13 satisfied. LHS=0.0, RHS=13000
# Constraint _C14 satisfied. LHS=0.0, RHS=18000
# Constraint _C15 satisfied. LHS=0.0, RHS=12000
# Constraint _C16 satisfied. LHS=0.0, RHS=8000
# Constraint _C17 satisfied. LHS=0.0, RHS=12000
# Constraint _C18 satisfied. LHS=0.0, RHS=17000
# Constraint _C19 satisfied. LHS=0.0, RHS=11000
# Constraint _C20 satisfied. LHS=0.0, RHS=16000
# Constraint _C21 satisfied. LHS=0.0, RHS=10000
# Constraint _C22 satisfied. LHS=0.0, RHS=9000
# Constraint _C23 satisfied. LHS=0.0, RHS=13000
# Constraint _C24 satisfied. LHS=0.0, RHS=18000
# Constraint _C25 satisfied. LHS=0.0, RHS=12000
# Constraint _C26 satisfied. LHS=0.0, RHS=17000
# Constraint _C27 satisfied. LHS=0.0, RHS=11000
# Constraint _C28 satisfied. LHS=0.0, RHS=7000
# Constraint _C29 satisfied. LHS=0.0, RHS=11000
# Constraint _C30 satisfied. LHS=0.0, RHS=16000
# Constraint _C31 satisfied. LHS=0.0, RHS=10000
# Constraint _C32 satisfied. LHS=0.0, RHS=15000
# Constraint _C33 satisfied. LHS=0.0, RHS=9000
# Constraint _C34 satisfied. LHS=0.0, RHS=5000
# Constraint _C35 satisfied. LHS=0.0, RHS=8000
# Constraint _C36 satisfied. LHS=0.0, RHS=10000
# Constraint _C37 satisfied. LHS=0.0, RHS=7000
# Constraint _C38 satisfied. LHS=0.0, RHS=9000
# Constraint _C39 satisfied. LHS=0.0, RHS=6000
# Constraint _C40 satisfied. LHS=0.0, RHS=4000
# Constraint _C41 satisfied. LHS=0.0, RHS=6000
# Constraint _C42 satisfied. LHS=0.0, RHS=9000
# Constraint _C43 satisfied. LHS=0.0, RHS=6000
# Constraint _C44 satisfied. LHS=0.0, RHS=8000
# Constraint _C45 satisfied. LHS=0.0, RHS=5000
# Constraint _C46 satisfied. LHS=0.0, RHS=6000
# Constraint _C47 satisfied. LHS=0.0, RHS=10000
# Constraint _C48 satisfied. LHS=0.0, RHS=12000
# Constraint _C49 satisfied. LHS=0.0, RHS=9000
# Constraint _C50 satisfied. LHS=0.0, RHS=11000
# Constraint _C51 satisfied. LHS=0.0, RHS=8000
# Constraint _C52 satisfied. LHS=0.0, RHS=5000
# Constraint _C53 satisfied. LHS=0.0, RHS=9000
# Constraint _C54 satisfied. LHS=0.0, RHS=11000
# Constraint _C55 satisfied. LHS=0.0, RHS=8000
# Constraint _C56 satisfied. LHS=0.0, RHS=10000
# Constraint _C57 satisfied. LHS=0.0, RHS=7000

# %%
print(pulp.LpStatus[model.status])
# Out:
# Optimal
